# %%
#!pip install pandas_datareader to validate crypto pricing with specific date
import pandas_datareader as web
import datetime as dt
from datetime import date
import pandas as pd
import seaborn as sns
import matplotlib.patches as patches
import matplotlib.pyplot as plt

start = dt.datetime(2021,9,1)
end = dt.datetime(2022,6,30)

# %%
BTC_Hist = web.DataReader('BTC-USD','yahoo', start, end)
BTC_Hist = BTC_Hist.reset_index()

# %%
ETH_Hist = web.DataReader('ETH-USD','yahoo', start, end)
ETH_Hist = ETH_Hist.reset_index()

# %%
MANA_Hist = web.DataReader('MANA-USD','yahoo', start, end)
MANA_Hist = MANA_Hist.reset_index()

# %%
SAND_Hist = web.DataReader('SAND-USD','yahoo', start, end)
SAND_Hist = SAND_Hist.reset_index()

# %%
GALA_Hist = web.DataReader('GALA-USD', 'yahoo', start, end)
GALA_Hist = GALA_Hist.reset_index()

# %%
colors = {'red': '#ff207c', 'grey': '#42535b', 'blue': '#207cff', 'orange': '#ffa320', 'green': '#00ec8b'}
config_ticks = {'size': 14, 'color': colors['grey'], 'labelcolor': colors['grey']}
config_title = {'size': 18, 'color': colors['grey'], 'ha': 'left', 'va': 'baseline'}

# %%
def get_max_row(crypto):
    column = crypto["Adj Close"]
    max_value = column.max()
    index = column.idxmax()
    return max_value, index

# %%
def get_min_row(crypto):
    column = crypto["Adj Close"]
    min_value = column.min()
    index = column.idxmin()
    return min_value, index

# %%
def get_charts(data, title):
    plt.rc('figure', figsize=(15, 10))
    
    fig, axes = plt.subplots(2, 1, 
                gridspec_kw={'height_ratios': [3, 1]})
    fig.tight_layout(pad=3)
    fig.suptitle(title, fontsize=16)
    
    date = data['Date']
    close = data['Close']
    vol = data['Volume']
    
    plot_price = axes[0]
    plot_price.plot(date, close, color=colors['blue'], 
    linewidth=2, label='Price')
    plot_price.set_ylabel('Price (in USD)', fontsize=14)
    plot_price.set_xlabel('Date', fontsize=14)
    
    
    plot_vol = axes[1]
    plot_vol.bar(date, vol, width=15, color='darkgrey')
    plt.xlabel('Date', fontsize=14)
    plt.ylabel('Volume (in millions)', fontsize=14)

# %%
BTC_Hist_max_price, index = get_max_row(BTC_Hist)
BTC_Hist_min_price, index = get_min_row(BTC_Hist)

BTC_percentage_change = (BTC_Hist_max_price/BTC_Hist_min_price)*100

# %%
BTC = BTC_Hist[BTC_Hist['Date']== '2021-10-28']
get_charts(BTC_Hist, 'BTC price during 28th Oct is {0:.2f}. After Facebook announced changed name and it rise to {1}% more.'.format(BTC.iloc[0]['Close'],int(BTC_percentage_change)))

# %%
ETH_Hist_max_price, index = get_max_row(ETH_Hist)
ETH_Hist_min_price, index = get_min_row(ETH_Hist)

ETH_percentage_change = (ETH_Hist_max_price/ETH_Hist_min_price)*100

# %%
ETH = ETH_Hist[ETH_Hist['Date']== '2021-10-28']
get_charts(ETH_Hist, 'ETH price during 28th Oct is {0:.2f}. After Facebook announced changed name and it rise to {1}% more.'.format(ETH.iloc[0]['Close'],int(ETH_percentage_change)))

# %%
MANA_Hist_max_price, index = get_max_row(MANA_Hist)
MANA_Hist_min_price, index = get_min_row(MANA_Hist)

MANA_percentage_change = (MANA_Hist_max_price/MANA_Hist_min_price)*100

# %%
MANA = MANA_Hist[MANA_Hist['Date']== '2021-10-28']
get_charts(MANA_Hist, 'Mana price during 28th Oct is {0:.2f}. After Facebook announced changed name and it rise to {1}% more.'.format(MANA.iloc[0]['Close'],int(MANA_percentage_change)))

# %%
SAND_Hist_max_price, index = get_max_row(SAND_Hist)
SAND_Hist_min_price, index = get_min_row(SAND_Hist)

SAND_percentage_change = (SAND_Hist_max_price/SAND_Hist_min_price)*100

# %%
SAND = SAND_Hist[SAND_Hist['Date']== '2021-10-28']
get_charts(SAND_Hist, 'SAND price during 28th Oct is {0:.2f}. After Facebook announced changed name and it rise to {1}% more.'.format(SAND.iloc[0]['Close'],int(SAND_percentage_change)))

# %%
GALA_Hist_max_price, index = get_max_row(GALA_Hist)
GALA_Hist_min_price, index = get_min_row(GALA_Hist)

GALA_percentage_change = (GALA_Hist_max_price/GALA_Hist_min_price)*100

# %%
GALA = GALA_Hist[GALA_Hist['Date']== '2021-10-28']
get_charts(GALA_Hist, 'GALA price during 28th Oct is {0:.2f}. After Facebook announced changed name and it rise to {1}% more.'.format(GALA.iloc[0]['Close'],int(GALA_percentage_change)))
